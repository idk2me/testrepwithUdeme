# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path = r'C:\webdrivers\chromedriver.exe')
#driver.implicitly_wait(30)

# %%
brands = [] #List to store brand ofthe product
ratings = [] #List to store rating of the product
products = [] #List to store name of the product
promos = [] #List to store promo offers
prices = [] #List to store price of the product
discounted_prices = [] #List to store discounted price of the product
offers = [] #List to store number of offers of the product
shipping_cost = [] #List to store shipping charges of the product

# %%
#driver.get("https://www.newegg.com/p/pl?Submit=StoreIM&Depa=1&Category=38&PageSize=96")
driver.get("https://www.newegg.com/p/pl?Submit=StoreIM&Depa=1&Category=38&PageSize=96")
delay = 10 # seconds
while True:
    try:
        WebDriverWait(driver, delay).until(EC.visibility_of_element_located(
            (By.XPATH, "//div[@class='bottom-button-area']")))
        print("Page is ready!")
        break # it will break from the loop once the specific element will be present. 
    except TimeoutException:
        print("Loading took too much time!-Try again")
# Out:
# Page is ready!

# %%
content = driver.page_source
soup = BeautifulSoup(content)
containers = soup.findAll('div', attrs = {'class': 'item-info'})
print(len(containers))
print(BeautifulSoup.prettify(containers[0]))
# Out:
# 41
# <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#   <a class="item-brand" href="https://www.newegg.com/MSI/BrandStore/ID-1312">
#    <img alt="MSI" src="//c1.neweggimages.com/Brandimage_70x28//Brand1312.gif" title="MSI"/>
#   </a>
#   <!--rating info-->
#   <a class="item-rating" href="https://www.newegg.com/msi-geforce-gtx-1660-super-gtx-1660-super-ventus-xs-oc/p/N82E16814137475?Item=N82E16814137475&amp;SortField=0&amp;SummaryType=0&amp;PageSize=96&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 4">
#    <i class="rating rating-4">
#    </i>
#    <span class="item-rating-num">
#     (26)
#    </span>
#   </a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/msi-geforce-gtx-1660-super-gtx-1660-super-ventus-xs-oc/p/N82E16814137475?Item=N82E16814137475&amp;quicklink=true" title="View Details">
#   MSI GeForce GTX 1660 SUPER DirectX 12 GTX 1660 SUPER VENTUS XS OC Video Card
#  </a>
#  <!--promption info-->
#  <p class="item-promo">
#   <i class="item-promo-icon">
#   </i>
#   + $10 off w/ promo code VGAPCMS4644, limited offer
#  </p>
#  <!--feature-->
#  <ul class="item-features">
#   <li>
#    <strong>
#     Max Resolution:
#    </strong>
#    7680 x 4320
#   </li>
#   <li>
#    <strong>
#     DisplayPort:
#    </strong>
#    3 x DisplayPort 1.4
#   </li>
#   <li>
#    <strong>
#     HDMI:
#    </strong>
#    1 x HDMI 2.0b
#   </li>
#   <li>
#    <strong>
#     Card Dimensions (L x H):
#    </strong>
#    8.03" x 5.04"
#   </li>
#   <li>
#    <strong>
#     Model #:
#    </strong>
#    1660SuperVentusXSOC
#   </li>
#   <li>
#    <strong>
#     Item #:
#    </strong>
#    N82E16814137475
#   </li>
#   <li>
#    <strong>
#     Return Policy:
#    </strong>
#    <a href="https://kb.newegg.com/Article/Index/12/3?id=1167#44" target="_blank" title="Standard Return Policy(New Window)">
#     Standard Return Policy
#    </a>
#   </li>
#  </ul>
#  <div class="item-action">
#   <!--price-->
#   <ul class="price">
#    <li class="price-was">
#    </li>
#    <li class="price-map">
#    </li>
#    <li class="price-current">
#     <span class="price-current-label">
#     </span>
#     $
#     <strong>
#      249
#     </strong>
#     <sup>
#      .99
#     </sup>
#     <a class="price-current-num" href="https://www.newegg.com/msi-geforce-gtx-1660-super-gtx-1660-super-ventus-xs-oc/p/N82E16814137475?Item=N82E16814137475&amp;buyingoptions=New">
#      (5 Offers)
#     </a>
#     <span class="price-current-range">
#      <abbr title="to">
#       –
#      </abbr>
#     </span>
#    </li>
#    <li class="price-save">
#     <span class="price-save-endtime price-save-endtime-current">
#     </span>
#     <span class="price-save-endtime price-save-endtime-another" style="display:none;">
#     </span>
#    </li>
#    <li class="price-note">
#     <span class="price-note-dollar" data-price="$239.99">
#      $239.99
#     </span>
#     <span class="price-note-label">
#      after
#     </span>
#     <span class="price-note-dollar">
#      $10.00
#     </span>
#     <span class="price-note-label">
#      rebate card
#     </span>
#    </li>
#    <li class="price-ship">
#     Free Shipping
#    </li>
#   </ul>
#   <!--egg point-->
#   <!--financing-->
#   <!--button-->
#   <div class="item-operate">
#    <div class="item-button-area">
#     <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/msi-geforce-gtx-1660-super-gtx-1660-super-ventus-xs-oc/p/N82E16814137475?Item=N82E16814137475');" title="View Details" type="button">
#      View Details
#      <i class="fa fa-caret-right">
#      </i>
#     </button>
#    </div>
#    <!--compare-->
#    <div class="item-compare-box">
#     <label class="form-checkbox">
#      <input autocomplete="off" name="CompareItem" neg-itemnumber="14-137-475" type="checkbox" value="CompareItem_14-137-475"/>
#      <span class="form-checkbox-title">
#       Compare
#      </span>
#     </label>
#    </div>
#    <script type="text/javascript">
#     Biz.Product.CompareConfig2019.compareItems.push("14-137-475");
#                                 var itemThumbs = new Object();
#                                 itemThumbs.subCategoryId = 48;
#                                 itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                 itemThumbs.itemNumber = "14-137-475";
#                                 itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-137-475-V01.jpg";
#                                 itemThumbs.description = "MSI GeForce GTX 1660 SUPER DirectX 12 GTX 1660 SUPER VENTUS XS OC Video Card";
#                                 itemThumbs.productUrl = "/msi-geforce-gtx-1660-super-gtx-1660-super-ventus-xs-oc/p/N82E16814137475?Item=N82E16814137475";
#                                 Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#    </script>
#   </div>
#   <!--ExtendWarranty PopUp-->
#   <input class="open-popup" id="ew_N82E16814137475" type="hidden"/>
#   <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814137475" type="hidden"/>
#  </div>
# </div>

# %%
for container in containers:
    brand = container.find('img')['title']
    brands.append(brand)
    rating = container.find('a', href = True, attrs = {'class': 'item-rating'})
    rating = rating['title'] if rating is not None else ""
    ratings.append(rating)
    #print(rating)
    product = container.find('a', href = True, attrs = {'class': 'item-title'}).text
    products.append(product)
    promo = container.find('p', attrs = {'class': 'item-promo'}).text
    promos.append(promo)
    #print(product + promo)
    amount = container.find('div', attrs = {'class': 'item-action'})
    price = amount.strong.text + amount.sup.text
    prices.append(price)
    discounted_price = container.find('span', attrs = {'class': 'price-note-dollar'})
    #print(discounted_price)
    discounted_price = discounted_price['data-price'] if discounted_price is not None else ''
    discounted_prices.append(discounted_price)
    offer = container.find('a', href = True, attrs = {'class': 'price-current-num'})
    offer = offer.text if offer is not None else ""
    offers.append(offer)
    shipping = container.find('li', attrs = {'class': 'price-ship'}).text.strip()
    shipping_cost.append(shipping)

# print(len(brands))
# print(len(discounted_prices))
# print(len(ratings))
# print(len(offers))
# print(len(products))

# %%
# container = containers[1]
# container.find('span', attrs={'class':'price-note-dollar'})['data-price']

# %%
df = pd.DataFrame({'Brand Name':brands, 'Ratings':ratings, 'Product Name':products,
                   'Valid Promos':promos, 'Price':prices, 'Discounted Price':discounted_prices,
                   'Offers':offers, 'Shipping Charges':shipping_cost})

df
# Out:
#        Brand Name     Ratings  \
# 0             MSI  Rating + 4
# 1            ASUS  Rating + 4
# 2             MSI  Rating + 4
# 3   Sapphire Tech  Rating + 5
# 4            EVGA  Rating + 4
# 5        GIGABYTE  Rating + 4
# 6            ASUS
# 7          ASRock  Rating + 4
# 8            EVGA  Rating + 4
# 9            EVGA  Rating + 4
# 10       GIGABYTE  Rating + 4
# 11       GIGABYTE  Rating + 4
# 12           ASUS  Rating + 4
# 13       GIGABYTE  Rating + 3
# 14           EVGA  Rating + 5
# 15           EVGA  Rating + 5
# 16            MSI  Rating + 3
# 17         ASRock  Rating + 4
# 18       GIGABYTE  Rating + 3
# 19           ASUS  Rating + 2
# 20  Sapphire Tech  Rating + 4
# 21         ASRock  Rating + 4
# 22           EVGA  Rating + 4
# 23       GIGABYTE  Rating + 5
# 24            XFX  Rating + 4
# 25            MSI  Rating + 5
# 26            MSI  Rating + 5
# 27            MSI  Rating + 5
# 28            MSI  Rating + 4
# 29            MSI  Rating + 3
# 30           EVGA  Rating + 4
# 31           EVGA  Rating + 5
# 32       GIGABYTE  Rating + 4
# 33           EVGA  Rating + 5
# 34            XFX
# 35           ASUS  Rating + 4
# 36         ASRock  Rating + 3
# 37       GIGABYTE  Rating + 4
# 38         ASRock  Rating + 4
# 39       GIGABYTE  Rating + 4
# 40         ASRock  Rating + 5
#
#                                          Product Name  \
# 0   MSI GeForce GTX 1660 SUPER DirectX 12 GTX 1660...
# 1   ASUS GeForce RTX 2070 Super Overclocked 8G EVO...
# 2   MSI GeForce RTX 2060 DirectX 12 RTX 2060 VENTU...
# 3   SAPPHIRE PULSE Radeon RX 5600 XT DirectX 12 10...
# 4   EVGA GeForce GTX 1660 Ti SC ULTRA GAMING, 06G-...
# 5   GIGABYTE Radeon RX 570 DirectX 12 GV-RX570GAMI...
# 6   ASUS GeForce RTX 2060 Overclocked 6G GDDR6 Dua...
# 7   ASRock Phantom Gaming D Radeon RX 570 DirectX ...
# 8   EVGA GeForce RTX 2080 Ti XC HYBRID GAMING, 11G...
# 9   EVGA GeForce RTX 2060 XC GAMING, 6GB GDDR6, HD...
# 10  GIGABYTE Radeon RX 580 GAMING 8G (rev. 2.0) Gr...
# 11  GIGABYTE Radeon RX 5500 XT DirectX 12 GV-R55XT...
# 12  ASUS TUF Gaming GeForce RTX 2060 OC Edition 6G...
# 13  GIGABYTE Radeon RX 5600 XT DirectX 12 GV-R56XT...
# 14  EVGA GeForce RTX 2080 SUPER XC HYBRID GAMING, ...
# 15  EVGA GeForce GTX 1660 SC ULTRA GAMING, 06G-P4-...
# 16  MSI Radeon RX 5700 XT DirectX 12 RX 5700 XT ME...
# 17  ASRock Phantom Gaming X Radeon RX Vega 56 Dire...
# 18  GIGABYTE Radeon RX 5700 XT GAMING OC 8G Graphi...
# 19  ASUS Dual GeForce RTX 2080 Ti DirectX 12 DUAL-...
# 20  Sapphire PULSE Radeon RX 580 8GB GDDR5 PCI-E D...
# 21  ASRock Phantom Gaming D Radeon RX 570 DirectX ...
# 22  EVGA GeForce RTX 2080 Ti XC GAMING, 11G-P4-238...
# 23  GIGABYTE GeForce GTX 1660 SUPER DirectX 12 GV-...
# 24  XFX Radeon RX 580 DirectX 12 RX-580P8RFD6 Vide...
# 25  MSI Radeon RX 570 DirectX 12 RX 570 8GT OC Vid...
# 26  MSI GeForce RTX 2060 DirectX 12 RTX 2060 GAMIN...
# 27  MSI GeForce GTX 1660 SUPER DirectX 12 GTX 1660...
# 28  MSI Radeon RX 5700 DirectX 12 RX 5700 MECH OC ...
# 29  MSI GeForce RTX 2080 SUPER DirectX 12 RTX 2080...
# 30  EVGA GeForce RTX 2080 Ti FTW3 ULTRA GAMING, 11...
# 31  EVGA GeForce RTX 2070 SUPER KO GAMING Video Ca...
# 32  GIGABYTE GeForce RTX 2070 Super GAMING OC 3X 8...
# 33  EVGA GeForce RTX 2080 Ti DirectX 12 11G-P4-228...
# 34  XFX Radeon RX 5600 XT RX-56XT6DF46 Video Card ...
# 35  ASUS ROG Strix Radeon RX 570 O4G Gaming OC Edi...
# 36  ASRock Challenger D Radeon RX 5500 XT DirectX ...
# 37  GIGABYTE GeForce RTX 2070 DirectX 12 GV-N2070W...
# 38  ASRock Radeon RX 5700 XT DirectX 12 RX 5700 XT...
# 39  GIGABYTE GeForce RTX 2080 SUPER GAMING OC WHIT...
# 40  ASRock Challenger D Radeon RX 5600 XT RX5600XT...
#
#                                          Valid Promos     Price  \
# 0   + $10 off w/ promo code VGAPCMS4644, limited o...    249.99
# 1                                                        529.99
# 2   + $20 off w/ promo code VGAPCMS4653, limited o...    339.99
# 3   + $10 off w/ promo code VGAPCJY232, limited offer    289.99
# 4   Get Grip Game + EVGA Vehicle Skin w/ purchase,...    299.99
# 5           Get Xbox Game Pass w/ purchase, ends soon    119.99
# 6                                                        349.99
# 7           Get Xbox Game Pass w/ purchase, ends soon    119.99
# 8   Free Deliver Us The Moon Game w/ purchase, whi...  1,399.99
# 9   Free Deliver Us The Moon Game w/ purchase, whi...    369.99
# 10          Get Xbox Game Pass w/ purchase, ends soon    169.99
# 11  Get Ghost Recon, RE3 & Xbox Game Pass w/ purch...    199.99
# 12                                                       319.99
